# %%
#Imports the library
import pandas as pd

# %%
#creates the variable df that stores our csv file as a pandas dataframe
df = pd.read_csv('https://raw.githubusercontent.com/UncertainQubit/binder/master/Melbourne_housing_FULL.csv')

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
df.shape
# Out:
# (34857, 21)

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df['SellerG'].head()
# Out:
# 0    Jellis
# 1    Biggin
# 2    Biggin
# 3    Rounds
# 4    Biggin
# Name: SellerG, dtype: object

# %%
df['SellerG'].value_counts()
# Out:
# Jellis           3359
# Nelson           3236
# Barry            3235
# hockingstuart    2623
# Marshall         2027
#                  ...
# Naison              1
# Blue                1
# Icon                1
# T                   1
# Meallin             1
# Name: SellerG, Length: 388, dtype: int64

# %%
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

plt.figure(figsize=(20,10))
sns.set_style('whitegrid')
sns.regplot(x=df['Rooms'], y=df['Price'])

# %% [markdown]
# # Your turn
# We've included a dataset of ramen ratings from a popular website below. Using the `ramendf` dataframe answer the questions below. Remember the essential steps of d

# %%
ramendf = pd.read_csv('https://raw.githubusercontent.com/UncertainQubit/binder/master/ramen-ratings.csv')

# %% [markdown]
# Your challenge is to try and discover some basic insights about the dataset. Try and answer the questions below:
# * What are the top three countries ramen comes from?
# * What is the most popular brand?
# * How many different types of ramen were reviewed.
#
# _Hint: use the value_counts() function, head() function, and shape() function_

# %%
ramendf.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
ramendf['Review #'].value_counts()
# Out:
# 2047    1
# 1240    1
# 1196    1
# 1194    1
# 1192    1
#        ..
# 2478    1
# 429     1
# 2476    1
# 427     1
# 2049    1
# Name: Review #, Length: 2580, dtype: int64
